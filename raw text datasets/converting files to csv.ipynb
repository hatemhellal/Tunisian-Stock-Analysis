# %%
import os
import pandas as pd

l=os.listdir()
l=[i for i in l if i.startswith("histo")]

# %%
with open("histo_cotation_2016.txt","r") as f:
    sentences=f.readlines()

# %%
keys=sentences[0]
keys=" ".join(keys.split())

# %%
def adjust(string):
    return " ".join(string.split())

# %%
l=[i.strip() for i in sentences[2:]]

# %%
keys = keys.split(" ")
dic = {}
for i in keys:
    dic[i] = 0

# %%
len(keys)
# Out:
# 12

# %%
sentences[1].split(" ")
# Out:
# ['----------',
#  '-------',
#  '------',
#  '------------------',
#  '-----------',
#  '-----------',
#  '-----------',
#  '-----------',
#  '------------------',
#  '---------------',
#  '-----------------',
#  '-------',
#  '',
#  '\n']

# %%
lengths=[len(i)+1 for i in sentences[1].split(" ")]

# %%
sum(lengths)
# Out:
# 157

# %%
keys
# Out:
# ['SEANCE',
#  'GROUPE',
#  'CODE',
#  'VALEUR',
#  'OUVERTURE',
#  'CLOTURE',
#  'PLUS_BAS',
#  'PLUS_HAUT',
#  'QUANTITE_NEGOCIEE',
#  'NB_TRANSACTION',
#  'CAPITAUX',
#  'IND_RES']

# %%
len(keys)==len(lengths)
# Out:
# False

# %%
def get_list(l,start,end):
    container=[]
    for i in l:
        container.append(i[start:end])
    return container

# %%
get_list(l,sum(lengths[0:0]),sum(lengths[0:1]))
# Out:
# ['04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
#  '04/01/2016 ',
# ...

# %%
for i in range(len(keys)):
    dic[keys[i]]=get_list(l,sum(lengths[0:i]),sum(lengths[0:i+1]))

# %%
dic1={}
for i in dic.keys():
    dic1[i]=0
for i in dic.keys():
    dic1[i]=dic[i][0]

# %%
df=pd.DataFrame.from_dict(dic)

# %%
df
# Out:
#              SEANCE    GROUPE     CODE               VALEUR     OUVERTURE  \
# 0       04/01/2016        11   100010   MONOPRIX                  14.190
# 1       04/01/2016        11   110025   SFBT                      22.800
# 2       04/01/2016        11   120040   TUNISAIR                   0.820
# 3       04/01/2016        11   160015   ATTIJARI BANK             24.190
# 4       04/01/2016        11   180045   BIAT                      76.350
# ...             ...       ...      ...                  ...           ...
# 126060  30/12/2016        51   770001   OFFICEPLAST                3.080
# 126061  30/12/2016        52   766001   MAGHREB INTERN PUB         0.000
# 126062  30/12/2016        71   722002   F1BIAT1016 T+1.2%          0.000
# 126063  30/12/2016        71   722007   F2BIAT0420 T+1.7%          0.000
# 126064  30/12/2016        99   503001   STIP                       1.950
#
#              CLOTURE      PLUS_BAS     PLUS_HAUT    QUANTITE_NEGOCIEE  \
# ...
